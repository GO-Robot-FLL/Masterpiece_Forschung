# %% [markdown]
# # Daten Analyse von der Teen Tech Expo
#
# **File name = Robotik_Expo.csv**
#
# Hier werden die Daten die wir gesammelt Analysiert mit einer Linear Regression Funktion. Der Ziel it Aussgen zu Treffen, wo wir mit den Alter der Kinder sagen können ob die Ausstellung, oder das Austellungsstück empfehlenswert ist oder nicht. Dadurch erleichtert es die Planung der Expo, da man gezielte Ausstellungsstücke haben kann, und die Quote der zufriedenen Schülern steigt

# %%
#import all the required modules
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
# bring the data into dataframe
df = pd.read_csv("Robotik_Expo4.csv",sep=';', header=[0])

# %%
df.iloc[0:7]
#df['Frage_4']
# Out:
#    Alter  Frage_1  Frage_2  Frage_3  Frage_4  Sastisfaction_Rate
# 0     16        5        5        5        5                 100
# 1     13        5        5        5        5                 100
# 2     15        5        5        5        5                 100
# 3     19        5        5        5        5                 100
# 4     14        5        5        5        5                 100
# 5     17        5        5        5        5                 100
# 6     14        5        5        5        5                 100

# %%
x = df.iloc[:, [True, False, False, False, False, False]]
y = df.iloc[:, [False, True, False, False, False, False]]
x_new = x.head(7)
y_new = y.head(7)


print (y_new)
# Out:
#    Frage_1
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5

# %%
x = df.iloc[:, [False, True, False, False, False, False]]
y = df.iloc[:, [True, False, False, False, False, False]]

# Use a scatter plot for plotting a graph of TV vs Sales
plt.scatter(x, y)

# Add axis labels for clarity (x : TV budget, y : Sales)
plt.xlabel("Alter")
plt.ylabel("Frage 1 Scale: 1(stimme nicht zu) - 5(stimme zu)")

# Add plot title 
plt.title("Ich hatte Spaß an der Ausstellung")
# Out:
# Text(0.5, 1.0, 'Ich hatte Spaß an der Ausstellung')

# %%
x = df.iloc[:, [False, False, True, False, False, False]]
y = df.iloc[:, [True, False, False, False, False, False]]

# Use a scatter plot for plotting a graph of TV vs Sales
plt.scatter(x, y)

# Add axis labels for clarity (x : TV budget, y : Sales)
plt.xlabel("Frage 2 Scale: 1(stimme nicht zu) - 5(stimme zu)")
plt.ylabel("Alter")

# Add plot title 
plt.title("Ich habe was neues gelernt an der Ausstellung")
# Out:
# Text(0.5, 1.0, 'Ich habe was neues gelernt an der Ausstellung')

# %%
x = df.iloc[:, [False, False, False, True, False, False]]
y = df.iloc[:, [True, False, False, False, False, False]]

# Use a scatter plot for plotting a graph of TV vs Sales
plt.scatter(x, y)

# Add axis labels for clarity (x : TV budget, y : Sales)
plt.xlabel("Frage 2 Scale: 1(stimme nicht zu) - 5(stimme zu)")
plt.ylabel("Alter")

# Add plot title 
plt.title("Ich würde nochmal zur Ausstellung kommen")
# Out:
# Text(0.5, 1.0, 'Ich würde nochmal zur Ausstellung kommen')

# %%
x = df.iloc[:, [False, False, False, False, True, False]]
y = df.iloc[:, [True, False, False, False, False, False]]

# Use a scatter plot for plotting a graph of TV vs Sales
plt.scatter(x, y)

# Add axis labels for clarity (x : TV budget, y : Sales)
plt.xlabel("Frage 4 Scale: 1(sehr schlecht) - 5(sehr gut)")
plt.ylabel("Alter")

# Add plot title 
plt.title("Die Ausstellung hat meine Interesse an Robotik erweckt")
# Out:
# Text(0.5, 1.0, 'Die Ausstellung hat meine Interesse an Robotik erweckt')

# %%
x = df.iloc[:, [False, False, False, False, False, True]]
y = df.iloc[:, [True, False, False, False, False, False]]

# Use a scatter plot for plotting a graph of TV vs Sales
plt.scatter(x, y)

# Add axis labels for clarity (x : TV budget, y : Sales)
plt.xlabel("Satisfaction Rate")
plt.ylabel("Alter")

# Add plot title 
plt.title("Satisfaction Rate")
# Out:
# Text(0.5, 1.0, 'Satisfaction Rate')

# %% [markdown]
# # Making a Linear Regression Model

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
df.describe()
# Out:
#            Alter    Frage_1    Frage_2    Frage_3    Frage_4  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000
# mean   15.043478   4.673913   4.065217   4.826087   3.369565
# std     2.421721   0.634362   1.143137   0.437384   1.704356
# min    11.000000   3.000000   1.000000   3.000000   0.000000
# 25%    13.000000   5.000000   4.000000   5.000000   2.250000
# 50%    15.500000   5.000000   4.000000   5.000000   4.000000
# 75%    17.000000   5.000000   5.000000   5.000000   5.000000
# max    19.000000   5.000000   5.000000   5.000000   5.000000
#
#        Sastisfaction_Rate
# count           46.000000
# mean            84.565217
# std             16.958318
# min             30.000000
# 25%             70.000000
# 50%             85.000000
# 75%            100.000000
# max            100.000000

# %%
plt.title('Frage 1 Plot')
sns.distplot(df['Frage_1'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Relationship between Salary and Experience
plt.scatter(df['Alter'], df['Frage_1'], color = 'lightcoral')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.box(False)
plt.show()

# %%
# Splitting variables
X = df.iloc[:,:1]
y = df.iloc[:,1:2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#print(X_train, y_train)

# %%
#Linear Regression Model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

#print(X_train, y_train)

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Alter vs Frage_1 (Training Set)(Ich hatte Spaß an der Ausstellung)')
plt.xlabel('Frage 1')
plt.ylabel('Alter')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
plt.title('Frage 2 Plot')
sns.distplot(df['Frage_2'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Linear regression of Frage 2
# Splitting variables
X = df.iloc[:,:1]
y = df.iloc[:,2:3]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#print(X_train, y_train)

#Linear Regression Model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

#print(X_train, y_train)

# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Alter vs Frage_2 (Training Set)(Ich habe was neues gelernt an der Ausstellung)')
plt.xlabel('Frage 2')
plt.ylabel('Alter')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
#distribution plot Frage 3
plt.title('Frage 3 Plot')
sns.distplot(df['Frage_3'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Linear regression of Frage 3
# Splitting variables
X = df.iloc[:,:1]
y = df.iloc[:,3:4]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#print(X_train, y_train)

#Linear Regression Model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

#print(X_train, y_train)

# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Alter vs Frage_3 (Training Set)(Ich würde nochmal zur Ausstellung kommen)')
plt.xlabel('Frage 3')
plt.ylabel('Alter')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
#distribution Polt Frage 4
plt.title('Frage 4 Plot')
sns.distplot(df['Frage_4'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Linear regression of Frage 4
# Splitting variables
X = df.iloc[:,:1]
y = df.iloc[:,4:5]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#print(X_train, y_train)

#Linear Regression Model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

#print(X_train, y_train)

# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Alter vs Frage_4 (Training Set)(Die Ausstellung hat meine Interesse an Robotik erweckt)')
plt.xlabel('Frage 4')
plt.ylabel('Alter')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
plt.title('Satisfaction Rate Plot')
sns.distplot(df['Sastisfaction_Rate'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Linear regression of Satisfacton Rate
# Splitting variables
X = df.iloc[:,:1]
y = df.iloc[:,5:6]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#print(X_train, y_train)

#Linear Regression Model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

#print(X_train, y_train)

# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Alter vs Satisfaction Rate (Training Set)(Satisfaction Rate)')
plt.xlabel('Satisfaction Rate')
plt.ylabel('Alter')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
